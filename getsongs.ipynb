# %%
#imports
import os
import lyricsgenius as lg

# %%
#conecting to genius API
genius_acess_token = "Qf2dT2nlqEnEXSbwa5ZsCtz0I1fgrSrp72jK-FzmbUXMcy0Nwc8cIiKMFuuNRFCi"
genius = lg.Genius(genius_acess_token,timeout=20, skip_non_songs=True, excluded_terms = ["Remix", "Live" "Mix", "Medley", "Cover", "Version"])

# %%
#getting the list of songs for the given artist
songs = genius.search_artist('Twnety One Pilots')
# Out:
# Searching for songs by Twnety One Pilots...
#
# Changing artist name to '​twenty one pilots'
# Song 1: "Heathens"
# Song 2: "Stressed Out"
# Song 3: "Ride"
# Song 4: "Chlorine"
# Song 5: "Nico And The Niners"
# Song 6: "Car Radio"
# Song 7: "Heavydirtysoul"
# Song 8: "Tear in My Heart"
# Song 9: "My Blood"
# Song 10: "Morph"
# Song 11: "Holding On To You"
# Song 12: "Neon Gravestones"
# Song 13: "Levitate"
# Song 14: "Kitchen Sink"
# Song 15: "Migraine"
# Song 16: "Message Man"
# Song 17: "Jumpsuit"
# Song 18: "Level of Concern"
# Song 19: "Lane Boy"
# Song 20: "We Don’t Believe What’s on TV"
# Song 21: "Ode To Sleep"
# Song 22: "The Judge"
# Song 23: "Polarize"
# Song 24: "Pet Cheetah"
# Song 25: "Bandito"
# Song 26: "Guns for Hands"
# Song 27: "Hometown"
# Song 28: "Doubt"
# Song 29: "Smithereens"
# Song 30: "Fairly Local"
# Song 31: "The Hype"
# Song 32: "Not Today"
# Song 33: "House of Gold"
# Song 34: "Shy Away"
# Song 35: "Leave the City"
# Song 36: "Cancer"
# ...

# %%
#saving the lyrics as a json file for further analysis
songs.save_lyrics()
# Out:
# Wrote Lyrics_twentyonepilots.json.
